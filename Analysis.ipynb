# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head(5)
# Out:
#                                        Title Specialization Salary  \
# Программист Python  Программист, разработчик   not required     22
# Python Developer    Программист, разработчик   not required     38
# Программист Python     Programmer, developer   not required     30
# Python разработчик  Программист, разработчик   not required     23
# Python Developer    Программист, разработчик            300     20
#
#                                                                   Age  \
# Программист Python  Занятость: проектная работа, стажировка, части...
# Python Developer    Занятость: проектная работа, стажировка, части...
# Программист Python                              Employment: full time
# Python разработчик                        Занятость: полная занятость
# Python Developer     Занятость: частичная занятость, полная занятость
#
#                                                            Employment  \
# ...

# %%
data.sort_values(["Salary"])
data.head(5)
# Out:
#                                        Title Specialization Salary  \
# Программист Python  Программист, разработчик   not required     22
# Python Developer    Программист, разработчик   not required     38
# Программист Python     Programmer, developer   not required     30
# Python разработчик  Программист, разработчик   not required     23
# Python Developer    Программист, разработчик            300     20
#
#                                                                   Age  \
# Программист Python  Занятость: проектная работа, стажировка, части...
# Python Developer    Занятость: проектная работа, стажировка, части...
# Программист Python                              Employment: full time
# Python разработчик                        Занятость: полная занятость
# Python Developer     Занятость: частичная занятость, полная занятость
#
#                                                            Employment  \
# ...
